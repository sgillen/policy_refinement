# %%
import pandas as pd
file_name = "test_out/poop.csv"
df = pd.read_csv(file_name)[['post', 'config.algo', 'config.env_name', 'mdim_mean', 'cdim_mean', 'mdim_nan_mean', 'mdim_std', 'ureward_mean', 'ureward_std', 'nreward_mean', 'nreward_std', 'len_mean',
                             'cdim_nan_mean']]#, 'config.post']]
df
# Out:
#    post config.algo       config.env_name  mdim_mean  cdim_mean  \
# 0  iden         tqc         PandaReach-v1   0.768377   4.698512
# 1  iden         tqc  PandaPickAndPlace-v1   0.666572   2.596703
# 2  iden         tqc          PandaPush-v1   0.654800   3.159500
# 3  iden         tqc         PandaSlide-v1   0.566082   3.210033
# 4  iden         tqc         PandaStack-v1   0.615318   2.731194
# 5  iden         tqc         FetchReach-v1   0.637897   2.928267
# 6  iden         tqc  FetchPickAndPlace-v1   0.747473   4.675893
# 7  iden         tqc          FetchPush-v1   0.726656   4.989771
# 8  iden         tqc         FetchSlide-v1   0.829515   3.988568
#
#    mdim_nan_mean  mdim_std  ureward_mean  ureward_std  nreward_mean  \
# 0       0.768377  0.138885           0.0          0.0           0.0
# 1       0.666572  0.176967           0.0          0.0           0.0
# 2       0.654800  0.064513           0.0          0.0           0.0
# ...

# %%
algo = 'sac'

df.loc[(df['config.algo'] == algo) & (df['post']=='iden')]
# Out:
#     post config.algo          config.env_name  mdim_mean  cdim_mean  \
# 2   iden         sac     Walker2DBulletEnv-v0   1.267627  10.661319
# 6   iden         sac  HalfCheetahBulletEnv-v0   1.159261   8.502494
# 10  iden         sac       HopperBulletEnv-v0   1.253658   8.988719
# 14  iden         sac          AntBulletEnv-v0   1.616845  12.715175
# 18  iden         sac      ReacherBulletEnv-v0   0.668973   5.175844
#
#     mdim_nan_mean  mdim_std  ureward_mean  ureward_std  nreward_mean  \
# 2        1.267627  0.276100   2064.071153   681.336737   2064.071131
# 6        1.159261  0.097310   2793.418870     8.802347   2793.418774
# 10       1.253658  0.037805   2632.909979    11.854733   2632.909961
# 14       1.616845  0.094305   3096.743578    20.892738   3096.743555
# 18       0.668973  0.078518     14.296785    11.198746     14.296784
#
#     nreward_std  len_mean  cdim_nan_mean
# 2    681.336729     901.5      10.661319
# 6      8.802360    1000.0       8.502494
# ...

# %%
df.loc[(df['config.algo'] == algo) & (df['post']=='mdim_div_stable_nolen')]
# Out:
#                      post config.algo          config.env_name  mdim_mean  \
# 22  mdim_div_stable_nolen         sac     Walker2DBulletEnv-v0   1.509212
# 26  mdim_div_stable_nolen         sac  HalfCheetahBulletEnv-v0   0.850773
# 30  mdim_div_stable_nolen         sac       HopperBulletEnv-v0   1.272061
# 34  mdim_div_stable_nolen         sac          AntBulletEnv-v0   1.602583
# 38  mdim_div_stable_nolen         sac      ReacherBulletEnv-v0   0.659201
#
#     cdim_mean  mdim_nan_mean  mdim_std  ureward_mean  ureward_std  \
# 22  11.663536       1.509212  0.091286   2425.164689    11.097862
# 26   7.501945       0.850773  0.040166   2905.083812     9.214253
# 30   7.743398       1.272061  0.128143   2552.327188   630.237949
# 34  10.128900       1.602583  0.069083   3302.405103     8.773977
# 38   5.016239       0.659201  0.064921     14.331566    11.165095
#
#     nreward_mean  nreward_std  len_mean  cdim_nan_mean
# 22   2425.164648    11.097903    1000.0      11.663536
# ...

# %%
df.loc[(df['config.algo'] == algo) & (df['post']=='cdim_div_stable_nolen')]
# Out:
#                      post config.algo          config.env_name  mdim_mean  \
# 42  cdim_div_stable_nolen         sac     Walker2DBulletEnv-v0   1.450394
# 46  cdim_div_stable_nolen         sac  HalfCheetahBulletEnv-v0   0.842353
# 50  cdim_div_stable_nolen         sac       HopperBulletEnv-v0   1.263959
# 54  cdim_div_stable_nolen         sac          AntBulletEnv-v0   1.645045
# 58  cdim_div_stable_nolen         sac      ReacherBulletEnv-v0   0.668533
#
#     cdim_mean  mdim_nan_mean  mdim_std  ureward_mean  ureward_std  \
# 42  11.415395       1.450394  0.105592   2417.479719    15.653100
# 46   7.213833       0.842353  0.061818   2907.988306     4.763096
# 50   7.729097       1.263959  0.069648   2735.235891     7.367919
# 54   9.913432       1.645045  0.134248   3284.998846    15.772265
# 58   5.368259       0.668533  0.075045     14.130240    10.938813
#
#     nreward_mean  nreward_std  len_mean  cdim_nan_mean
# 42   2417.479761    15.653110    1000.0      11.415395
# ...

# %%
import pandas as pd
file_name = "keepers/ppo_a2c_100.csv"
df = pd.read_csv(file_name)[['config.train', 'config.algo', 'config.env_name', 'mdim_mean', 'mdim_nan_mean', 'mdim_std', 'ureward_mean', 'ureward_std', 'nreward_mean', 'nreward_std', 'len_mean']]
df
# Out:
#     config.train config.algo          config.env_name  mdim_mean  \
# 0          False         ppo     Walker2DBulletEnv-v0   1.963476
# 1          False         a2c     Walker2DBulletEnv-v0        NaN
# 2          False         ppo  HalfCheetahBulletEnv-v0   1.817264
# 3          False         a2c  HalfCheetahBulletEnv-v0   2.125698
# 4          False         ppo       HopperBulletEnv-v0   1.613065
# 5          False         a2c       HopperBulletEnv-v0   1.091405
# 6           True         ppo     Walker2DBulletEnv-v0   1.152133
# 7           True         a2c     Walker2DBulletEnv-v0   0.937504
# 8           True         ppo  HalfCheetahBulletEnv-v0   1.681537
# 9           True         a2c  HalfCheetahBulletEnv-v0   1.615918
# 10          True         ppo       HopperBulletEnv-v0   1.419093
# 11          True         a2c       HopperBulletEnv-v0   1.483334
#
#     mdim_nan_mean  mdim_std  ureward_mean  ureward_std  nreward_mean  \
# ...

# %%
df.loc[(df['config.algo'] == 'ppo') & (df['config.train']==False)]
# Out:
#    config.train config.algo          config.env_name  mdim_mean  \
# 0         False         ppo     Walker2DBulletEnv-v0   1.963476
# 2         False         ppo  HalfCheetahBulletEnv-v0   1.817264
# 4         False         ppo       HopperBulletEnv-v0   1.613065
#
#    mdim_nan_mean  mdim_std  ureward_mean  ureward_std  nreward_mean  \
# 0       1.963476  0.132894   2111.364508    10.776165     33.376486
# 2       1.817264  0.092955   2908.169612    38.828683     26.925796
# 4       1.613065  0.084308   2537.098882   263.534898     29.168804
#
#    nreward_std  len_mean
# 0     0.170349    1000.0
# 2     0.359502    1000.0
# 4     3.029838     966.4

# %%
df.loc[(df['config.algo'] == 'ppo') & (df['config.train']==True)]
# Out:
#     config.train config.algo          config.env_name  mdim_mean  \
# 6           True         ppo     Walker2DBulletEnv-v0   1.152133
# 8           True         ppo  HalfCheetahBulletEnv-v0   1.681537
# 10          True         ppo       HopperBulletEnv-v0   1.419093
#
#     mdim_nan_mean  mdim_std  ureward_mean  ureward_std  nreward_mean  \
# 6        1.152133  0.153365   1868.071133    27.120454     29.530500
# 8        1.681537  0.066835   2554.963687    70.415481     23.655577
# 10       1.419093  0.040547   2541.667945    41.778377     29.221334
#
#     nreward_std  len_mean
# 6      0.428721    1000.0
# 8      0.651954    1000.0
# 10     0.480323     995.7

# %%
df.loc[(df['config.algo'] == 'td3') & (df['config.train']==False)]
# Out:
#     config.train config.algo          config.env_name  mdim_mean  cdim_mean  \
# 2          False         td3     Walker2DBulletEnv-v0        NaN        NaN
# 8          False         td3  HalfCheetahBulletEnv-v0   1.418637   9.325105
# 14         False         td3       HopperBulletEnv-v0   1.233501   5.482480
# 20         False         td3          AntBulletEnv-v0   1.661431   8.565321
# 26         False         td3      ReacherBulletEnv-v0        NaN        NaN
#
#     mdim_nan_mean  mdim_std  ureward_mean  ureward_std  nreward_mean  \
# 2        1.385299       NaN   2052.887746   568.973756   2052.887692
# 8        1.418637  0.094321   2826.124755    14.489177   2826.124731
# 14       1.233501  0.105169   2679.315193    28.479300   2679.315210
# 20       1.661431  0.124652   3313.426100    41.518409   3313.426123
# 26            NaN       NaN     12.441167     5.627356     12.441167
#
#     nreward_std  len_mean  cdim_nan_mean
# 2    568.973735     917.5      10.117610
# ...

# %%
df.loc[(df['config.algo'] == 'tqc') & (df['config.train']==False)]
# Out:
#     config.train config.algo          config.env_name  mdim_mean  cdim_mean  \
# 5          False         tqc     Walker2DBulletEnv-v0        NaN        NaN
# 11         False         tqc  HalfCheetahBulletEnv-v0   1.420859   4.526387
# 17         False         tqc       HopperBulletEnv-v0   1.306618   7.230764
# 23         False         tqc          AntBulletEnv-v0   1.645090  10.461982
# 29         False         tqc      ReacherBulletEnv-v0        NaN        NaN
#
#     mdim_nan_mean  mdim_std  ureward_mean  ureward_std  nreward_mean  \
# 5        1.391070       NaN   2418.166841   755.757666   2418.166795
# 11       1.420859  0.063570   3683.604083    17.602738   3683.604077
# 17       1.306618  0.061219   2693.198463    12.604214   2693.198462
# 23       1.645090  0.219703   3418.044591   171.086013   3418.044580
# 29            NaN       NaN     15.299590     8.984380     15.299589
#
#     nreward_std  len_mean  cdim_nan_mean
# 5    755.757647     907.8       7.512200
# ...

# %%
df.loc[(df['config.algo'] == 'ddpg') & (df['config.train']==False)]
# Out:
#     config.train config.algo          config.env_name  mdim_mean  cdim_mean  \
# 4          False        ddpg     Walker2DBulletEnv-v0        NaN        NaN
# 10         False        ddpg  HalfCheetahBulletEnv-v0   1.263753   7.039615
# 16         False        ddpg       HopperBulletEnv-v0        NaN        NaN
# 22         False        ddpg          AntBulletEnv-v0   2.241480  12.098584
# 28         False        ddpg      ReacherBulletEnv-v0        NaN        NaN
#
#     mdim_nan_mean  mdim_std  ureward_mean  ureward_std  nreward_mean  \
# 4        1.113990       NaN   1015.078698   790.522622   1015.078680
# 10       1.263753  0.105984   2088.962962    95.069826   2088.963000
# 16       0.785918       NaN    949.633707   509.286164    949.633704
# 22       2.241480  0.109829   2394.688964    62.809585   2394.689014
# 28            NaN       NaN     16.514616    10.717869     16.514617
#
#     nreward_std  len_mean  cdim_nan_mean
# 4    790.522611     529.5       9.309079
# ...

# %%
import os
#os.makedirs('./keepers/')
df.to_csv(f"./keepers/{file_name}")

# %%
df.to_latex??
# Out:
# Signature:
# df.to_latex(
#     buf=None,
#     columns=None,
#     col_space=None,
#     header=True,
#     index=True,
#     na_rep='NaN',
#     formatters=None,
#     float_format=None,
#     sparsify=None,
#     index_names=True,
#     bold_rows=False,
#     column_format=None,
#     longtable=None,
#     escape=None,
#     encoding=None,
#     decimal='.',
#     multicolumn=None,
#     multicolumn_format=None,
#     multirow=None,
#     caption=None,
#     label=None,
# )
# Docstring:
# Render object to a LaTeX tabular, longtable, or nested table/tabular.
#
# Requires ``\usepackage{booktabs}``.  The output can be copy/pasted
# into a main LaTeX document or read from an external file
# with ``\input{table.tex}``.
#
# .. versionchanged:: 0.20.2
#    Added to Series.
#
# .. versionchanged:: 1.0.0
#    Added caption and label arguments.
#
# Parameters
# ----------
# buf : str, Path or StringIO-like, optional, default None
# ...
