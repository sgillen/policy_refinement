# %%
import pandas as pd
file_name = "test_out/hmmm.csv"
df = pd.read_csv(file_name)[['post', 'config.algo', 'config.env_name', 'mdim_mean', 'cdim_mean', 'mdim_nan_mean', 'cdim_nan_mean', 'mdim_std',  'cdim_std', 
                             'ureward_mean', 'ureward_std', 'nreward_mean', 'nreward_std', 'len_mean',]]#, 'config.post']]
df
# Out:
#                post config.algo          config.env_name  mdim_mean  \
# 0              iden         ppo     Walker2DBulletEnv-v0   1.689780
# 1              iden         td3     Walker2DBulletEnv-v0        NaN
# 2              iden         sac     Walker2DBulletEnv-v0        NaN
# 3              iden         tqc     Walker2DBulletEnv-v0        NaN
# 4              iden         ppo  HalfCheetahBulletEnv-v0   1.607997
# 5              iden         td3  HalfCheetahBulletEnv-v0   1.418637
# 6              iden         sac  HalfCheetahBulletEnv-v0   1.175308
# 7              iden         tqc  HalfCheetahBulletEnv-v0   1.420859
# 8              iden         ppo       HopperBulletEnv-v0   1.456749
# 9              iden         td3       HopperBulletEnv-v0   1.233501
# 10             iden         sac       HopperBulletEnv-v0   1.220068
# 11             iden         tqc       HopperBulletEnv-v0   1.306618
# 12             iden         ppo          AntBulletEnv-v0   2.449654
# 13             iden         td3          AntBulletEnv-v0   1.661431
# 14             iden         sac          AntBulletEnv-v0   1.634662
# 15             iden         tqc          AntBulletEnv-v0   1.645090
# 16             iden         ppo      ReacherBulletEnv-v0        NaN
# 17             iden         td3      ReacherBulletEnv-v0        NaN
# 18             iden         sac      ReacherBulletEnv-v0        NaN
# 19             iden         tqc      ReacherBulletEnv-v0        NaN
# 20  mdim_div_stable         ppo     Walker2DBulletEnv-v0   0.893430
# 21  mdim_div_stable         td3     Walker2DBulletEnv-v0   0.976935
# 22  mdim_div_stable         sac     Walker2DBulletEnv-v0   0.818683
# 23  mdim_div_stable         tqc     Walker2DBulletEnv-v0   1.072140
# 24  mdim_div_stable         ppo  HalfCheetahBulletEnv-v0   1.447349
# 25  mdim_div_stable         td3  HalfCheetahBulletEnv-v0   0.863297
# 26  mdim_div_stable         sac  HalfCheetahBulletEnv-v0   0.842272
# 27  mdim_div_stable         tqc  HalfCheetahBulletEnv-v0   1.254110
# 28  mdim_div_stable         ppo       HopperBulletEnv-v0   1.265346
# 29  mdim_div_stable         td3       HopperBulletEnv-v0   1.095542
# 30  mdim_div_stable         sac       HopperBulletEnv-v0   1.047838
# 31  mdim_div_stable         tqc       HopperBulletEnv-v0   1.207752
# 32  mdim_div_stable         ppo          AntBulletEnv-v0   1.932470
# 33  mdim_div_stable         td3          AntBulletEnv-v0   0.907992
# 34  mdim_div_stable         sac          AntBulletEnv-v0   0.906674
# 35  mdim_div_stable         tqc          AntBulletEnv-v0   1.007104
# 36  mdim_div_stable         ppo      ReacherBulletEnv-v0        NaN
# 37  mdim_div_stable         td3      ReacherBulletEnv-v0        NaN
# 38  mdim_div_stable         sac      ReacherBulletEnv-v0        NaN
# 39  mdim_div_stable         tqc      ReacherBulletEnv-v0        NaN
# 40  cdim_div_stable         ppo     Walker2DBulletEnv-v0   1.263076
# 41  cdim_div_stable         td3     Walker2DBulletEnv-v0   1.018008
# 42  cdim_div_stable         sac     Walker2DBulletEnv-v0   0.873909
# 43  cdim_div_stable         tqc     Walker2DBulletEnv-v0   1.079298
# 44  cdim_div_stable         ppo  HalfCheetahBulletEnv-v0   1.431210
# 45  cdim_div_stable         td3  HalfCheetahBulletEnv-v0   0.787481
# 46  cdim_div_stable         sac  HalfCheetahBulletEnv-v0   0.882009
# 47  cdim_div_stable         tqc  HalfCheetahBulletEnv-v0   1.185875
# 48  cdim_div_stable         ppo       HopperBulletEnv-v0   1.270773
# 49  cdim_div_stable         td3       HopperBulletEnv-v0   1.081477
# 50  cdim_div_stable         sac       HopperBulletEnv-v0   1.031912
# 51  cdim_div_stable         tqc       HopperBulletEnv-v0   1.181954
# 52  cdim_div_stable         ppo          AntBulletEnv-v0   1.994424
# 53  cdim_div_stable         td3          AntBulletEnv-v0   0.907150
# 54  cdim_div_stable         sac          AntBulletEnv-v0   0.912934
# 55  cdim_div_stable         tqc          AntBulletEnv-v0   0.996181
# 56  cdim_div_stable         ppo      ReacherBulletEnv-v0        NaN
# 57  cdim_div_stable         td3      ReacherBulletEnv-v0        NaN
# 58  cdim_div_stable         sac      ReacherBulletEnv-v0        NaN
# 59  cdim_div_stable         tqc      ReacherBulletEnv-v0        NaN
#
#     cdim_mean  mdim_nan_mean  cdim_nan_mean  mdim_std  cdim_std  ureward_mean  \
# 0    5.556138       1.689780       5.556138  0.118989  0.591567   2111.364508
# 1         NaN       1.385299      10.117610       NaN       NaN   2052.887746
# 2         NaN       1.326451       9.959648       NaN       NaN   2064.071153
# 3         NaN       1.391070       7.512200       NaN       NaN   2418.166841
# 4    4.743522       1.607997       4.743522  0.093637  0.356731   2908.169612
# 5    9.325105       1.418637       9.325105  0.094321  0.487351   2826.124755
# 6    8.382052       1.175308       8.382052  0.062030  0.426898   2793.418870
# 7    4.526387       1.420859       4.526387  0.063570  0.574148   3683.604083
# 8    4.888004       1.456749       4.888004  0.090701  1.139591   2537.098882
# 9    5.482480       1.233501       5.482480  0.105169  0.866199   2679.315193
# 10   7.242032       1.220068       7.242032  0.036209  0.735189   2632.909979
# 11   7.230764       1.306618       7.230764  0.061219  0.504941   2693.198463
# 12   6.007160       2.449654       6.007160  0.123148  0.595201   2883.673144
# 13   8.565321       1.661431       8.565321  0.124652  0.279705   3313.426100
# 14  12.529953       1.634662      12.529953  0.128199  0.483308   3096.743578
# 15  10.461982       1.645090      10.461982  0.219703  0.633767   3418.044591
# 16        NaN            NaN            NaN       NaN       NaN     17.434490
# 17        NaN            NaN            NaN       NaN       NaN     12.441167
# 18        NaN            NaN            NaN       NaN       NaN     14.296785
# 19        NaN            NaN            NaN       NaN       NaN     15.299590
# 20   5.545587       0.893430       5.545587  0.106209  0.523234   1852.950912
# 21   3.674251       0.976935       3.674251  0.060561  0.279707   2232.665557
# 22   8.928403       0.818683       8.928403  0.081479  0.711705   2228.755849
# 23   6.127374       1.072140       6.127374  0.072274  0.428221   2486.135421
# 24   4.666843       1.447349       4.666843  0.087625  0.462028   2838.930827
# 25   7.143770       0.863297       7.143770  0.015312  1.053260   2776.317561
# 26   8.275794       0.842272       8.275794  0.034283  0.587336   2821.650741
# 27   4.148677       1.254110       4.148677  0.033264  0.427420   3664.644430
# 28   3.977367       1.265346       3.977367  0.030061  0.445189   2529.253316
# 29   4.918926       1.095542       4.918926  0.077014  0.534639   2688.580567
# 30   4.946313       1.047838       4.946313  0.039026  0.591100   2557.693281
# 31   6.859908       1.207752       6.859908  0.043264  0.452710   2637.700075
# 32   5.462227       1.932470       5.462227  0.281272  0.472029   2668.207616
# 33   3.565535       0.907992       3.565535  0.076604  0.466523   3266.723065
# 34   2.545831       0.906674       2.545831  0.080759  0.307675   3018.321240
# 35   7.664236       1.007104       7.664236  0.070877  0.997953   3249.775454
# 36        NaN            NaN            NaN       NaN       NaN     18.741080
# 37        NaN            NaN            NaN       NaN       NaN     12.660576
# 38        NaN            NaN            NaN       NaN       NaN     15.079414
# 39        NaN            NaN            NaN       NaN       NaN     15.398968
# 40   5.191473       1.263076       5.191473  0.095975  0.530433   1966.477799
# 41   4.528058       1.018008       4.528058  0.079756  2.533210   2208.415839
# 42   8.543064       0.873909       8.543064  0.093300  0.806713   2212.636949
# 43   6.753393       1.079298       6.753393  0.051199  0.556895   2508.901911
# 44   4.923017       1.431210       4.923017  0.114805  0.393136   2774.666332
# 45   6.106138       0.787481       6.106138  0.027435  0.382944   2725.218246
# 46   8.068280       0.882009       8.068280  0.084600  0.377318   2817.188413
# 47   4.218651       1.185875       4.218651  0.059393  0.454654   3636.123652
# 48   5.684370       1.270773       5.684370  0.050065  0.528715   2487.693251
# 49   5.245162       1.081477       5.245162  0.047284  0.580278   2643.708081
# 50   5.859306       1.031912       5.859306  0.027482  0.489676   2523.092048
# 51   6.948805       1.181954       6.948805  0.036688  0.514656   2653.035400
# 52   5.776895       1.994424       5.776895  0.137310  0.692968   2557.910975
# 53   3.754888       0.907150       3.754888  0.053924  0.444279   3266.654514
# 54   2.552921       0.912934       2.552921  0.068155  0.195669   3032.946986
# 55   8.787636       0.996181       8.787636  0.064478  0.324497   3347.824762
# 56        NaN            NaN            NaN       NaN       NaN     19.102211
# 57        NaN            NaN            NaN       NaN       NaN     11.932328
# 58        NaN            NaN            NaN       NaN       NaN     13.399986
# 59        NaN            NaN            NaN       NaN       NaN     14.815078
#
#     ureward_std  nreward_mean  nreward_std  len_mean
# 0     10.776165     33.376486     0.170349    1000.0
# 1    568.973756   2052.887692   568.973735     917.5
# 2    681.336737   2064.071131   681.336729     901.5
# 3    755.757666   2418.166795   755.757647     907.8
# 4     38.828683     26.925796     0.359502    1000.0
# 5     14.489177   2826.124731    14.489161    1000.0
# 6      8.802347   2793.418774     8.802360    1000.0
# 7     17.602738   3683.604077    17.602688    1000.0
# 8    263.534898     29.168804     3.029838     966.4
# 9     28.479300   2679.315210    28.479283     998.0
# 10    11.854733   2632.909961    11.854681    1000.0
# 11    12.604214   2693.198462    12.604205    1000.0
# 12    55.249830     33.931773     0.650117    1000.0
# 13    41.518409   3313.426123    41.518435    1000.0
# 14    20.892738   3096.743555    20.892749    1000.0
# 15   171.086013   3418.044580   171.085960    1000.0
# 16     8.446329      2.223599     1.077247     150.0
# 17     5.627356     12.441167     5.627355     150.0
# 18    11.198746     14.296784    11.198746     150.0
# 19     8.984380     15.299589     8.984379     150.0
# 20    12.006782     29.291479     0.189803    1000.0
# 21    11.046849   2232.665601    11.046811    1000.0
# 22    11.692667   2228.755835    11.692704    1000.0
# 23     9.280600   2486.135425     9.280606    1000.0
# 24    40.163384     26.284736     0.371860    1000.0
# 25     9.838764   2776.317554     9.838718    1000.0
# 26     4.393615   2821.650732     4.393577    1000.0
# 27    14.555103   3664.644434    14.555063    1000.0
# 28     7.455003     29.078604     0.085709    1000.0
# 29     9.082861   2688.580566     9.082928    1000.0
# 30     9.820193   2557.693262     9.820196    1000.0
# 31    22.079898   2637.700073    22.079822    1000.0
# 32   267.619114     31.396421     3.149036    1000.0
# 33     7.979353   3266.723071     7.979360    1000.0
# 34    10.250006   3018.321265    10.250014    1000.0
# 35    12.615487   3249.775415    12.615452    1000.0
# 36     8.765355      2.390242     1.117936     150.0
# 37     5.589320     12.660576     5.589320     150.0
# 38    11.196715     15.079415    11.196716     150.0
# 39     9.331150     15.398968     9.331150     150.0
# 40    21.354537     31.086115     0.337573    1000.0
# 41    13.704942   2208.415869    13.704921    1000.0
# 42    10.291896   2212.636963    10.291879    1000.0
# 43    10.891603   2508.901953    10.891521    1000.0
# 44    29.437477     25.689732     0.272552    1000.0
# 45     8.718356   2725.218262     8.718315    1000.0
# 46     4.689073   2817.188452     4.689012    1000.0
# 47     9.621372   3636.123657     9.621348    1000.0
# 48    12.445691     28.600792     0.143087    1000.0
# 49     9.266073   2643.708081     9.266114    1000.0
# 50    10.629105   2523.092065    10.629144    1000.0
# 51    22.877001   2653.035425    22.877058    1000.0
# 52   258.243433     30.098576     3.038714    1000.0
# 53    11.953282   3266.654468    11.953295    1000.0
# 54    15.880194   3032.947095    15.880200    1000.0
# 55    11.863854   3347.824707    11.863837    1000.0
# 56     9.361978      2.436301     1.194029     150.0
# 57     6.133437     11.932328     6.133437     150.0
# 58    11.283678     13.399986    11.283678     150.0
# 59     8.629811     14.815079     8.629811     150.0

# %%
algo= 'sac'

df.loc[(df['config.algo'] == algo) & (df['post']=='iden')]
# Out:
#     post config.algo          config.env_name  mdim_mean  cdim_mean  \
# 2   iden         sac     Walker2DBulletEnv-v0        NaN        NaN
# 6   iden         sac  HalfCheetahBulletEnv-v0   1.175308   8.382052
# 10  iden         sac       HopperBulletEnv-v0   1.220068   7.242032
# 14  iden         sac          AntBulletEnv-v0   1.634662  12.529953
# 18  iden         sac      ReacherBulletEnv-v0        NaN        NaN
#
#     mdim_nan_mean  cdim_nan_mean  mdim_std  cdim_std  ureward_mean  \
# 2        1.326451       9.959648       NaN       NaN   2064.071153
# 6        1.175308       8.382052  0.062030  0.426898   2793.418870
# 10       1.220068       7.242032  0.036209  0.735189   2632.909979
# 14       1.634662      12.529953  0.128199  0.483308   3096.743578
# 18            NaN            NaN       NaN       NaN     14.296785
#
#     ureward_std  nreward_mean  nreward_std  len_mean
# 2    681.336737   2064.071131   681.336729     901.5
# 6      8.802347   2793.418774     8.802360    1000.0
# 10    11.854733   2632.909961    11.854681    1000.0
# 14    20.892738   3096.743555    20.892749    1000.0
# 18    11.198746     14.296784    11.198746     150.0

# %%
df.loc[(df['config.algo'] == algo) & (df['post']=='mdim_div_stable')]
# Out:
#                post config.algo          config.env_name  mdim_mean  \
# 22  mdim_div_stable         sac     Walker2DBulletEnv-v0   0.818683
# 26  mdim_div_stable         sac  HalfCheetahBulletEnv-v0   0.842272
# 30  mdim_div_stable         sac       HopperBulletEnv-v0   1.047838
# 34  mdim_div_stable         sac          AntBulletEnv-v0   0.906674
# 38  mdim_div_stable         sac      ReacherBulletEnv-v0        NaN
#
#     cdim_mean  mdim_nan_mean  cdim_nan_mean  mdim_std  cdim_std  ureward_mean  \
# 22   8.928403       0.818683       8.928403  0.081479  0.711705   2228.755849
# 26   8.275794       0.842272       8.275794  0.034283  0.587336   2821.650741
# 30   4.946313       1.047838       4.946313  0.039026  0.591100   2557.693281
# 34   2.545831       0.906674       2.545831  0.080759  0.307675   3018.321240
# 38        NaN            NaN            NaN       NaN       NaN     15.079414
#
#     ureward_std  nreward_mean  nreward_std  len_mean
# 22    11.692667   2228.755835    11.692704    1000.0
# 26     4.393615   2821.650732     4.393577    1000.0
# 30     9.820193   2557.693262     9.820196    1000.0
# 34    10.250006   3018.321265    10.250014    1000.0
# 38    11.196715     15.079415    11.196716     150.0

# %%
df.loc[(df['config.algo'] == algo) & (df['post']=='cdim_div_stable')]
# Out:
#                post config.algo          config.env_name  mdim_mean  \
# 42  cdim_div_stable         sac     Walker2DBulletEnv-v0   0.873909
# 46  cdim_div_stable         sac  HalfCheetahBulletEnv-v0   0.882009
# 50  cdim_div_stable         sac       HopperBulletEnv-v0   1.031912
# 54  cdim_div_stable         sac          AntBulletEnv-v0   0.912934
# 58  cdim_div_stable         sac      ReacherBulletEnv-v0        NaN
#
#     cdim_mean  mdim_nan_mean  cdim_nan_mean  mdim_std  cdim_std  ureward_mean  \
# 42   8.543064       0.873909       8.543064  0.093300  0.806713   2212.636949
# 46   8.068280       0.882009       8.068280  0.084600  0.377318   2817.188413
# 50   5.859306       1.031912       5.859306  0.027482  0.489676   2523.092048
# 54   2.552921       0.912934       2.552921  0.068155  0.195669   3032.946986
# 58        NaN            NaN            NaN       NaN       NaN     13.399986
#
#     ureward_std  nreward_mean  nreward_std  len_mean
# 42    10.291896   2212.636963    10.291879    1000.0
# 46     4.689073   2817.188452     4.689012    1000.0
# 50    10.629105   2523.092065    10.629144    1000.0
# 54    15.880194   3032.947095    15.880200    1000.0
# 58    11.283678     13.399986    11.283678     150.0

# %%
import pandas as pd
file_name = "keepers/ppo_a2c_100.csv"
df = pd.read_csv(file_name)[['config.train', 'config.algo', 'config.env_name', 'mdim_mean', 'mdim_nan_mean', 'mdim_std', 'ureward_mean', 'ureward_std', 'nreward_mean', 'nreward_std', 'len_mean']]
df
# Out:
#     config.train config.algo          config.env_name  mdim_mean  \
# 0          False         ppo     Walker2DBulletEnv-v0   1.963476
# 1          False         a2c     Walker2DBulletEnv-v0        NaN
# 2          False         ppo  HalfCheetahBulletEnv-v0   1.817264
# 3          False         a2c  HalfCheetahBulletEnv-v0   2.125698
# 4          False         ppo       HopperBulletEnv-v0   1.613065
# 5          False         a2c       HopperBulletEnv-v0   1.091405
# 6           True         ppo     Walker2DBulletEnv-v0   1.152133
# 7           True         a2c     Walker2DBulletEnv-v0   0.937504
# 8           True         ppo  HalfCheetahBulletEnv-v0   1.681537
# 9           True         a2c  HalfCheetahBulletEnv-v0   1.615918
# 10          True         ppo       HopperBulletEnv-v0   1.419093
# 11          True         a2c       HopperBulletEnv-v0   1.483334
#
#     mdim_nan_mean  mdim_std  ureward_mean  ureward_std  nreward_mean  \
# 0        1.963476  0.132894   2111.364508    10.776165     33.376486
# 1        0.933991       NaN    905.954950   276.436180     38.493285
# 2        1.817264  0.092955   2908.169612    38.828683     26.925796
# 3        2.125698  0.159355   2097.729587    38.287512     32.796229
# 4        1.613065  0.084308   2537.098882   263.534898     29.168804
# 5        1.091405  0.126574    768.694332   346.149968     13.005136
# 6        1.152133  0.153365   1868.071133    27.120454     29.530500
# 7        0.937504  0.007751   1001.688195     2.008234     42.560912
# 8        1.681537  0.066835   2554.963687    70.415481     23.655577
# 9        1.615918  0.092567   1988.964804    31.281858     31.095784
# 10       1.419093  0.040547   2541.667945    41.778377     29.221334
# 11       1.483334  0.025717   2239.173504    24.568394     37.883403
#
#     nreward_std  len_mean
# 0      0.170349    1000.0
# 1     11.745547     909.8
# 2      0.359502    1000.0
# 3      0.598593    1000.0
# 4      3.029838     966.4
# 5      5.856330     534.7
# 6      0.428721    1000.0
# 7      0.085329    1000.0
# 8      0.651954    1000.0
# 9      0.489065    1000.0
# 10     0.480323     995.7
# 11     0.415660    1000.0

# %%
df.loc[(df['config.algo'] == 'ppo') & (df['config.train']==False)]
# Out:
#    config.train config.algo          config.env_name  mdim_mean  \
# 0         False         ppo     Walker2DBulletEnv-v0   1.963476
# 2         False         ppo  HalfCheetahBulletEnv-v0   1.817264
# 4         False         ppo       HopperBulletEnv-v0   1.613065
#
#    mdim_nan_mean  mdim_std  ureward_mean  ureward_std  nreward_mean  \
# 0       1.963476  0.132894   2111.364508    10.776165     33.376486
# 2       1.817264  0.092955   2908.169612    38.828683     26.925796
# 4       1.613065  0.084308   2537.098882   263.534898     29.168804
#
#    nreward_std  len_mean
# 0     0.170349    1000.0
# 2     0.359502    1000.0
# 4     3.029838     966.4

# %%
df.loc[(df['config.algo'] == 'ppo') & (df['config.train']==True)]
# Out:
#     config.train config.algo          config.env_name  mdim_mean  \
# 6           True         ppo     Walker2DBulletEnv-v0   1.152133
# 8           True         ppo  HalfCheetahBulletEnv-v0   1.681537
# 10          True         ppo       HopperBulletEnv-v0   1.419093
#
#     mdim_nan_mean  mdim_std  ureward_mean  ureward_std  nreward_mean  \
# 6        1.152133  0.153365   1868.071133    27.120454     29.530500
# 8        1.681537  0.066835   2554.963687    70.415481     23.655577
# 10       1.419093  0.040547   2541.667945    41.778377     29.221334
#
#     nreward_std  len_mean
# 6      0.428721    1000.0
# 8      0.651954    1000.0
# 10     0.480323     995.7

# %%
df.loc[(df['config.algo'] == 'td3') & (df['config.train']==False)]
# Out:
#     config.train config.algo          config.env_name  mdim_mean  cdim_mean  \
# 2          False         td3     Walker2DBulletEnv-v0        NaN        NaN
# 8          False         td3  HalfCheetahBulletEnv-v0   1.418637   9.325105
# 14         False         td3       HopperBulletEnv-v0   1.233501   5.482480
# 20         False         td3          AntBulletEnv-v0   1.661431   8.565321
# 26         False         td3      ReacherBulletEnv-v0        NaN        NaN
#
#     mdim_nan_mean  mdim_std  ureward_mean  ureward_std  nreward_mean  \
# 2        1.385299       NaN   2052.887746   568.973756   2052.887692
# 8        1.418637  0.094321   2826.124755    14.489177   2826.124731
# 14       1.233501  0.105169   2679.315193    28.479300   2679.315210
# 20       1.661431  0.124652   3313.426100    41.518409   3313.426123
# 26            NaN       NaN     12.441167     5.627356     12.441167
#
#     nreward_std  len_mean  cdim_nan_mean
# 2    568.973735     917.5      10.117610
# 8     14.489161    1000.0       9.325105
# 14    28.479283     998.0       5.482480
# 20    41.518435    1000.0       8.565321
# 26     5.627355     150.0            NaN

# %%
df.loc[(df['config.algo'] == 'tqc') & (df['config.train']==False)]
# Out:
#     config.train config.algo          config.env_name  mdim_mean  cdim_mean  \
# 5          False         tqc     Walker2DBulletEnv-v0        NaN        NaN
# 11         False         tqc  HalfCheetahBulletEnv-v0   1.420859   4.526387
# 17         False         tqc       HopperBulletEnv-v0   1.306618   7.230764
# 23         False         tqc          AntBulletEnv-v0   1.645090  10.461982
# 29         False         tqc      ReacherBulletEnv-v0        NaN        NaN
#
#     mdim_nan_mean  mdim_std  ureward_mean  ureward_std  nreward_mean  \
# 5        1.391070       NaN   2418.166841   755.757666   2418.166795
# 11       1.420859  0.063570   3683.604083    17.602738   3683.604077
# 17       1.306618  0.061219   2693.198463    12.604214   2693.198462
# 23       1.645090  0.219703   3418.044591   171.086013   3418.044580
# 29            NaN       NaN     15.299590     8.984380     15.299589
#
#     nreward_std  len_mean  cdim_nan_mean
# 5    755.757647     907.8       7.512200
# 11    17.602688    1000.0       4.526387
# 17    12.604205    1000.0       7.230764
# 23   171.085960    1000.0      10.461982
# 29     8.984379     150.0            NaN

# %%
df.loc[(df['config.algo'] == 'ddpg') & (df['config.train']==False)]
# Out:
#     config.train config.algo          config.env_name  mdim_mean  cdim_mean  \
# 4          False        ddpg     Walker2DBulletEnv-v0        NaN        NaN
# 10         False        ddpg  HalfCheetahBulletEnv-v0   1.263753   7.039615
# 16         False        ddpg       HopperBulletEnv-v0        NaN        NaN
# 22         False        ddpg          AntBulletEnv-v0   2.241480  12.098584
# 28         False        ddpg      ReacherBulletEnv-v0        NaN        NaN
#
#     mdim_nan_mean  mdim_std  ureward_mean  ureward_std  nreward_mean  \
# 4        1.113990       NaN   1015.078698   790.522622   1015.078680
# 10       1.263753  0.105984   2088.962962    95.069826   2088.963000
# 16       0.785918       NaN    949.633707   509.286164    949.633704
# 22       2.241480  0.109829   2394.688964    62.809585   2394.689014
# 28            NaN       NaN     16.514616    10.717869     16.514617
#
#     nreward_std  len_mean  cdim_nan_mean
# 4    790.522611     529.5       9.309079
# 10    95.069814    1000.0       7.039615
# 16   509.286161     357.1       4.220627
# 22    62.809541    1000.0      12.098584
# 28    10.717869     150.0            NaN

# %%
import os
#os.makedirs('./keepers/')
df.to_csv(f"./keepers/{file_name}")

# %%
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-115-24269ef5d429> in <module>
#       1 import os
# ----> 2 os.makedirs('./keepers/')
#       3 df.to_csv("./keepers/ppo_a2c_100.csv")
#
# ~/anaconda3/envs/baselines/lib/python3.6/os.py in makedirs(name, mode, exist_ok)
#     218             return
#     219     try:
# --> 220         mkdir(name, mode)
#     221     except OSError:
#     222         # Cannot rely on checking for EEXIST, since the operating system
#
# FileExistsError: [Errno 17] File exists: './keepers/'
