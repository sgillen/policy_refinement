# %%
import pandas as pd
from IPython.display import display
#file_name = "test_out/panda0.csv"
#file_name = "test_out/panda_actor.csv"
#file_name = "keep_csv/ddpg_a2c_01_001_2.csv"
#file_name =  "test_out/classic2.csv"
#file_name = "test_out/pendulum_br.csv"

#file_name = "test_out/ddpg_a2c
file_name = "test_out/adim_all.csv"
file_name = "test_out/panda_seeded.csv"
file_name = "test_out/pendulum_seeded.csv"

df = pd.read_csv(file_name)[['post', 'config.algo', 'config.env_name', 'mdim_mean', 'cdim_mean', 'cdim_std', 'ureward_mean', 'ureward_std', 'nreward_mean', 'nreward_std', 'len_mean', 'cdim_nan_mean']]#, 'config.post']]
df
# Out:
#                    post config.algo config.env_name  mdim_mean  cdim_mean  \
# 0                  iden         a2c     Pendulum-v0   0.098062   2.528605
# 1                  iden         ppo     Pendulum-v0   0.152887   5.554552
# 2                  iden        ddpg     Pendulum-v0   0.129272   5.629622
# 3                  iden         sac     Pendulum-v0   0.169108   4.982265
# 4                  iden         td3     Pendulum-v0   0.125985   4.410599
# 5                  iden         tqc     Pendulum-v0   0.171006   5.332531
# 6   postprocess_default         a2c     Pendulum-v0   0.097943   2.302047
# 7   postprocess_default         ppo     Pendulum-v0   0.146056   5.510650
# 8   postprocess_default        ddpg     Pendulum-v0   0.131902   5.754818
# 9   postprocess_default         sac     Pendulum-v0   0.147559   4.578204
# 10  postprocess_default         td3     Pendulum-v0   0.121653   4.382466
# 11  postprocess_default         tqc     Pendulum-v0   0.129709   5.081123
#
# ...

# %%
post_dict = {}
for post in df['post']:
    post_dict[post] = 1 
    
# for post in post_dict.keys():
#     display(df[df['post'] == post])
    
for post in post_dict.keys():
    dfp = df[df['post'] == post]
    print(post)
    dfd = dfp.drop('post', axis=1, inplace=False)
    display(dfd)
# Out:
# iden
#    config.algo          config.env_name  mdim_mean  cdim_mean  cdim_std  \
# 0          ppo     Walker2DBulletEnv-v0   1.560541   5.336190  0.661308
# 1          td3     Walker2DBulletEnv-v0   1.296572  10.881104  3.099028
# 2          sac     Walker2DBulletEnv-v0   1.267627  10.661319  2.938591
# 3          tqc     Walker2DBulletEnv-v0   1.305009   9.415485  0.884697
# 4          a2c     Walker2DBulletEnv-v0   0.656925   4.435246  1.142944
# 5         ddpg     Walker2DBulletEnv-v0   1.076574  10.004348  0.762019
# 6          ppo  HalfCheetahBulletEnv-v0   1.573944   5.134705  0.367146
# 7          td3  HalfCheetahBulletEnv-v0   1.374065   8.956402  0.515706
# 8          sac  HalfCheetahBulletEnv-v0   1.159261   8.502494  0.486957
# 9          tqc  HalfCheetahBulletEnv-v0   1.454502   5.840621  0.346749
# 10         a2c  HalfCheetahBulletEnv-v0   1.643780   4.731259  0.440995
# 11        ddpg  HalfCheetahBulletEnv-v0   1.284576   7.332742  0.728594
# ...

# %% [markdown]
# # Pybullet Locomotion, Mesh dimensions ignoring initial transients

# %%
import pandas as pd
file_name = "keepers/full_len_dim.csv"
#file_name = "keepers/bullet_but_it_works.csv"

df = pd.read_csv(file_name)[['post', 'config.algo', 'config.env_name', 'mdim_mean', 'mdim_std', 'cdim_mean', 'cdim_std', 'ureward_mean', 'len_mean']]
df
# Out:
#                post config.algo          config.env_name  mdim_mean  mdim_std  \
# 0              iden         ppo     Walker2DBulletEnv-v0   1.689780  0.118989
# 1              iden         td3     Walker2DBulletEnv-v0        NaN       NaN
# 2              iden         sac     Walker2DBulletEnv-v0        NaN       NaN
# 3              iden         tqc     Walker2DBulletEnv-v0        NaN       NaN
# 4              iden         ppo  HalfCheetahBulletEnv-v0   1.607997  0.093637
# 5              iden         td3  HalfCheetahBulletEnv-v0   1.418637  0.094321
# 6              iden         sac  HalfCheetahBulletEnv-v0   1.175308  0.062030
# 7              iden         tqc  HalfCheetahBulletEnv-v0   1.420859  0.063570
# 8              iden         ppo       HopperBulletEnv-v0   1.456749  0.090701
# 9              iden         td3       HopperBulletEnv-v0   1.233501  0.105169
# 10             iden         sac       HopperBulletEnv-v0   1.220068  0.036209
# ...

# %% [markdown]
# ## PPO

# %%
algo = 'ppo'
display(df.loc[(df['config.algo'] == algo) & (df['post'] == 'iden')])
display(df.loc[(df['config.algo'] == algo) & (df['post'] == 'mdim_div_stable')])
display(df.loc[(df['config.algo'] == algo) & (df['post'] == 'cdim_div_stable')])
# Out:
#     post config.algo          config.env_name  mdim_mean  mdim_std  cdim_mean  \
# 0   iden         ppo     Walker2DBulletEnv-v0   1.689780  0.118989   5.556138
# 4   iden         ppo  HalfCheetahBulletEnv-v0   1.607997  0.093637   4.743522
# 8   iden         ppo       HopperBulletEnv-v0   1.456749  0.090701   4.888004
# 12  iden         ppo          AntBulletEnv-v0   2.449654  0.123148   6.007160
# 16  iden         ppo      ReacherBulletEnv-v0        NaN       NaN        NaN
#
#     cdim_std  ureward_mean  len_mean
# 0   0.591567   2111.364508    1000.0
# 4   0.356731   2908.169612    1000.0
# 8   1.139591   2537.098882     966.4
# 12  0.595201   2883.673144    1000.0
# 16       NaN     17.434490     150.0
#                post config.algo          config.env_name  mdim_mean  mdim_std  \
# 20  mdim_div_stable         ppo     Walker2DBulletEnv-v0   0.893430  0.106209
# 24  mdim_div_stable         ppo  HalfCheetahBulletEnv-v0   1.447349  0.087625
# ...

# %% [markdown]
# # TD3

# %%
algo = 'td3'
display(df.loc[(df['config.algo'] == algo) & (df['post'] == 'iden')])
display(df.loc[(df['config.algo'] == algo) & (df['post'] == 'mdim_div_stable')])
display(df.loc[(df['config.algo'] == algo) & (df['post'] == 'cdim_div_stable')])
# Out:
#     post config.algo          config.env_name  mdim_mean  mdim_std  cdim_mean  \
# 1   iden         td3     Walker2DBulletEnv-v0        NaN       NaN        NaN
# 5   iden         td3  HalfCheetahBulletEnv-v0   1.418637  0.094321   9.325105
# 9   iden         td3       HopperBulletEnv-v0   1.233501  0.105169   5.482480
# 13  iden         td3          AntBulletEnv-v0   1.661431  0.124652   8.565321
# 17  iden         td3      ReacherBulletEnv-v0        NaN       NaN        NaN
#
#     cdim_std  ureward_mean  len_mean
# 1        NaN   2052.887746     917.5
# 5   0.487351   2826.124755    1000.0
# 9   0.866199   2679.315193     998.0
# 13  0.279705   3313.426100    1000.0
# 17       NaN     12.441167     150.0
#                post config.algo          config.env_name  mdim_mean  mdim_std  \
# 21  mdim_div_stable         td3     Walker2DBulletEnv-v0   0.976935  0.060561
# 25  mdim_div_stable         td3  HalfCheetahBulletEnv-v0   0.863297  0.015312
# ...

# %% [markdown]
# # SAC

# %%
algo = 'sac'
display(df.loc[(df['config.algo'] == algo) & (df['post'] == 'iden')])
display(df.loc[(df['config.algo'] == algo) & (df['post'] == 'mdim_div_stable')])
display(df.loc[(df['config.algo'] == algo) & (df['post'] == 'cdim_div_stable')])
# Out:
#     post config.algo          config.env_name  mdim_mean  mdim_std  cdim_mean  \
# 2   iden         sac     Walker2DBulletEnv-v0        NaN       NaN        NaN
# 6   iden         sac  HalfCheetahBulletEnv-v0   1.175308  0.062030   8.382052
# 10  iden         sac       HopperBulletEnv-v0   1.220068  0.036209   7.242032
# 14  iden         sac          AntBulletEnv-v0   1.634662  0.128199  12.529953
# 18  iden         sac      ReacherBulletEnv-v0        NaN       NaN        NaN
#
#     cdim_std  ureward_mean  len_mean
# 2        NaN   2064.071153     901.5
# 6   0.426898   2793.418870    1000.0
# 10  0.735189   2632.909979    1000.0
# 14  0.483308   3096.743578    1000.0
# 18       NaN     14.296785     150.0
#                post config.algo          config.env_name  mdim_mean  mdim_std  \
# 22  mdim_div_stable         sac     Walker2DBulletEnv-v0   0.818683  0.081479
# 26  mdim_div_stable         sac  HalfCheetahBulletEnv-v0   0.842272  0.034283
# ...

# %% [markdown]
# # TQC

# %%
algo = 'tqc'
display(df.loc[(df['config.algo'] == algo) & (df['post'] == 'iden')])
display(df.loc[(df['config.algo'] == algo) & (df['post'] == 'mdim_div_stable')])
display(df.loc[(df['config.algo'] == algo) & (df['post'] == 'cdim_div_stable')])
# Out:
#     post config.algo          config.env_name  mdim_mean  mdim_std  cdim_mean  \
# 3   iden         tqc     Walker2DBulletEnv-v0        NaN       NaN        NaN
# 7   iden         tqc  HalfCheetahBulletEnv-v0   1.420859  0.063570   4.526387
# 11  iden         tqc       HopperBulletEnv-v0   1.306618  0.061219   7.230764
# 15  iden         tqc          AntBulletEnv-v0   1.645090  0.219703  10.461982
# 19  iden         tqc      ReacherBulletEnv-v0        NaN       NaN        NaN
#
#     cdim_std  ureward_mean  len_mean
# 3        NaN   2418.166841     907.8
# 7   0.574148   3683.604083    1000.0
# 11  0.504941   2693.198463    1000.0
# 15  0.633767   3418.044591    1000.0
# 19       NaN     15.299590     150.0
#                post config.algo          config.env_name  mdim_mean  mdim_std  \
# 23  mdim_div_stable         tqc     Walker2DBulletEnv-v0   1.072140  0.072274
# 27  mdim_div_stable         tqc  HalfCheetahBulletEnv-v0   1.254110  0.033264
# ...

# %%
#import os
#os.makedirs('./keepers/')
#df.to_csv(f"./keepers/full_no_len_dim1")

# %% [markdown]
# # Pybullet, full episode trajectories

# %%
import pandas as pd
#file_name = "keepers/full_len_dim.csv"
file_name = "keep_csv/bullet_works_rewards.csv"

df = pd.read_csv(file_name)[['post', 'config.algo', 'config.env_name', 'mdim_mean', 'mdim_std', 'cdim_mean', 'cdim_std','ureward_mean', 'ureward_std']]
df
# Out:
#                                     post config.algo          config.env_name  \
# 0                                   iden         ppo     Walker2DBulletEnv-v0
# 1                                   iden         td3     Walker2DBulletEnv-v0
# 2                                   iden         sac     Walker2DBulletEnv-v0
# 3                                   iden         tqc     Walker2DBulletEnv-v0
# 4                                   iden         ppo  HalfCheetahBulletEnv-v0
# 5                                   iden         td3  HalfCheetahBulletEnv-v0
# 6                                   iden         sac  HalfCheetahBulletEnv-v0
# 7                                   iden         tqc  HalfCheetahBulletEnv-v0
# 8                                   iden         ppo       HopperBulletEnv-v0
# 9                                   iden         td3       HopperBulletEnv-v0
# 10                                  iden         sac       HopperBulletEnv-v0
# ...

# %% [markdown]
# # PPO

# %%
algo = 'ppo'
display(df.loc[(df['config.algo'] == algo) & (df['post'] == 'iden')])
display(df.loc[(df['config.algo'] == algo) & (df['post'] == 'DualRewardDiv_mdim_safe_stable_nolen')])
display(df.loc[(df['config.algo'] == algo) & (df['post'] == 'DualRewardDiv_cdim_safe_stable_nolen')])
# Out:
#     post config.algo          config.env_name  mdim_mean  mdim_std  cdim_mean  \
# 0   iden         ppo     Walker2DBulletEnv-v0   1.560541  0.145203   5.336190
# 4   iden         ppo  HalfCheetahBulletEnv-v0   1.573944  0.093851   5.134705
# 8   iden         ppo       HopperBulletEnv-v0   1.433970  0.085089   4.877648
# 12  iden         ppo          AntBulletEnv-v0   2.429570  0.159144   5.393572
# 16  iden         ppo      ReacherBulletEnv-v0   0.751389  0.061976   4.512856
#
#     cdim_std  ureward_mean  ureward_std
# 0   0.661308   2111.364508    10.776165
# 4   0.367146   2908.169612    38.828683
# 8   0.840819   2537.098882   263.534898
# 12  1.053460   2883.673144    55.249830
# 16  1.815593     17.434490     8.446329
#                                     post config.algo          config.env_name  \
# 20  DualRewardDiv_mdim_safe_stable_nolen         ppo     Walker2DBulletEnv-v0
# 24  DualRewardDiv_mdim_safe_stable_nolen         ppo  HalfCheetahBulletEnv-v0
# ...

# %% [markdown]
# # TD3

# %%
algo = 'td3'
display(df.loc[(df['config.algo'] == algo) & (df['post'] == 'iden')])
display(df.loc[(df['config.algo'] == algo) & (df['post'] == 'DualRewardDiv_mdim_safe_stable_nolen')])
display(df.loc[(df['config.algo'] == algo) & (df['post'] == 'DualRewardDiv_cdim_safe_stable_nolen')])
# Out:
#     post config.algo          config.env_name  mdim_mean  mdim_std  cdim_mean  \
# 1   iden         td3     Walker2DBulletEnv-v0   1.296572  0.192960  10.881104
# 5   iden         td3  HalfCheetahBulletEnv-v0   1.374065  0.082803   8.956402
# 9   iden         td3       HopperBulletEnv-v0   1.240117  0.086367   6.282698
# 13  iden         td3          AntBulletEnv-v0   1.710029  0.101798   9.815890
# 17  iden         td3      ReacherBulletEnv-v0   0.634532  0.090405   4.283022
#
#     cdim_std  ureward_mean  ureward_std
# 1   3.099028   2052.887746   568.973756
# 5   0.515706   2826.124755    14.489177
# 9   0.631378   2679.315193    28.479300
# 13  0.389471   3313.426100    41.518409
# 17  2.327324     12.441167     5.627356
#                                     post config.algo          config.env_name  \
# 21  DualRewardDiv_mdim_safe_stable_nolen         td3     Walker2DBulletEnv-v0
# 25  DualRewardDiv_mdim_safe_stable_nolen         td3  HalfCheetahBulletEnv-v0
# ...

# %% [markdown]
# # SAC

# %%
algo = 'sac'
display(df.loc[(df['config.algo'] == algo) & (df['post'] == 'iden')])
display(df.loc[(df['config.algo'] == algo) & (df['post'] == 'DualRewardDiv_mdim_safe_stable_nolen')])
display(df.loc[(df['config.algo'] == algo) & (df['post'] == 'DualRewardDiv_cdim_safe_stable_nolen')])

# %% [markdown]
# # TQC

# %%
algo = 'tqc'
display(df.loc[(df['config.algo'] == algo) & (df['post'] == 'iden')])
display(df.loc[(df['config.algo'] == algo) & (df['post'] == 'DualRewardDiv_mdim_safe_stable_nolen')])
display(df.loc[(df['config.algo'] == algo) & (df['post'] == 'DualRewardDiv_cdim_safe_stable_nolen')])
